# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20304/130313570.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading https://files.pythonhosted.org/packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl (292kB)
# Requirement already satisfied: numpy>=1.15 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (3.4.2)
# Collecting scipy>=1.0 (from seaborn)
#   Downloading https://files.pythonhosted.org/packages/90/39/b9452a3879b0baea4041d6b344bfad37aacfaadaafe945b47bb475ab8c7a/scipy-1.7.1-cp38-cp38-win_amd64.whl (33.7MB)
# Requirement already satisfied: pandas>=0.23 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.7.1 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 21.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.3.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (3.4.2)
# WARNING: You are using pip version 19.2.3, however version 21.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy>=1.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\housing.csv')

# %%
print(df1.head())
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
sns.scatterplot(data=df1, x = 'RM', y='LSTAT')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='LSTAT'>

# %%
sns.lineplot(data=df1, x='RM', y='MEDV')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.boxplot(data=df1, x='RM', y='MEDV')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.pairplot(data=df1)

# %%
corr = df1.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f,ax=plt.subplots(figsize=(11,9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
