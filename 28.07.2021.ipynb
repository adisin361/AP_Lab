# %%
list1=[1 ,2 ,'physics', 'chem', 'java']
print(list1[4])
# Out:
# java

# %%
print(list1[2:5])
# Out:
# ['physics', 'chem', 'java']

# %%
print(len(list1))
# Out:
# 5

# %%
print(max(list1)) # as list1 is mixed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10300/2707063036.py in <module>
# ----> 1 print(max(list1))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
list2=[1,2,3,4,5,6]
print(max(list2))
# Out:
# 6

# %%
print(min(list2))
# Out:
# 1

# %%
list2 = [6,7,8,9,10,11]
print (cmp(list2, list3)) # not in python 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10300/3729694033.py in <module>
#       1 list2 = [6,7,8,9,10,11]
# ----> 2 print (cmp(list2, list3))
#
# NameError: name 'cmp' is not defined

# %%
# q1
a = [1,2,3,4,5]
print(max(a))
# Out:
# 5

# %%
# q2
print(sum(a))
# Out:
# 15

# %%
# q3
print(len(a))
# Out:
# 5

# %%
# q4
b = [5, 6, 7, 8]
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, [5, 6, 7, 8], [5, 6, 7, 8], 5, 6, 7, 8, 5, 6, 7, 8, [5, 6, 7, 8], [5, 6, 7, 8], [5, 6, 7, 8], [5, 6, 7, 8]]

# %%
# q5
c=[1,3,5,7,9]
c.remove(3)
print(c)
# Out:
# [1, 5, 7, 9]

# %%
# q6
c.insert(2, 5)
print(c)
# Out:
# [1, 5, 5, 7, 9, 3, 3, 3, 3, 3, 3]

# %%
c.pop()
print(c)
# Out:
# [1, 5, 5, 7, 9]

# %%
# dictionary 
# q7
d1={'Name': 'Aditya', 'Subject': 'AP Lab'}
d2={'CGPS': 9.5, 'Location': 'BBSR'}
d3={**d1, **d2}
print(d3)
# Out:
# {'Name': 'Aditya', 'Subject': 'AP Lab', 'CGPS': 9.5, 'Location': 'BBSR'}

# %%
# q8
del d1['Name']
print(d1)
# Out:
# {'Subject': 'AP Lab'}

# %%
# q9
d4={'b': 2, 'a': 3, 'c': 4, 'd': 7}
s = sorted(d4)
print(s)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# tuple
# q10
tpl=(1,2,4,5,7,8)
x=str(tpl)
print(x)
# Out:
# (1, 2, 4, 5, 7, 8)

# %%
# q11
lst=[1,2,3,4]
print(lst)
tpll=tuple(lst)
print(tpll)
# Out:
# [1, 2, 3, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10300/2330519612.py in <module>
#       2 lst=[1,2,3,4]
#       3 print(lst)
# ----> 4 tpll=tuple(lst)
#       5 print(tpll)
#
# TypeError: 'tuple' object is not callable

# %%
# q12
a_tuple = ((1, "a"), (2, "b"))

tuple_as_dictionary = dict(a_tuple)

print(tuple_as_dictionary)
# Out:
# {1: 'a', 2: 'b'}
